# %%
A <- matrix(
  c(1,1,1,2,2,1,100,100,101,100,100,101),
  nrow = 6,
  ncol = 2,
  byrow = TRUE)

# %%
A
# Out:
#      [,1] [,2]
# [1,]   1    1
# [2,]   1    2
# [3,]   2    1
# [4,] 100  100
# [5,] 101  100
# [6,] 100  101

# %%
plot(A)
# Out:
# plot without title
